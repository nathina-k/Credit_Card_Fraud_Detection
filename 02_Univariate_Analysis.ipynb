# %% [markdown]
# # <font color='blue'>Credit Card Fraud Detecion</font>

# %% [markdown]
# ## Table of Contents
# 3. [Univariate Analysis](#c_ID)
#
#     3.1 [Box Plots](#c1_ID)
#
#     3.2 [Histograms](#c2_ID)

# %% [markdown]
# ## <a id="c_ID">3. Univariate Analysis</a>

# %% [markdown]
# ### <a id="c1_ID"> 3.1 Box Plots</a>

# %% [markdown]
# Box plots displays the distribution of numerical data based on the five number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. The ends of the box are the first and third quartiles. The horizontal line in the middle of the box represents the median. The whiskers of the boxplot are the two horizontal lines outside of the box and represent the minimum and maximum observations. Boxplots can also be used to detect outliers. Outliers are the observations found outside the whiskers of the boxplot, outside 1.5IQR (IQR = Q3 - Q1) above the third quartile or below the first quartile.

# %%
# Box plots for all numeric features
fig = plt.figure(figsize=(30,54))

ax1 = plt.subplot(6, 5, 1)
sns.boxplot(data = creditcard, y = "Time", ax=ax1)

ax2 = plt.subplot(6, 5, 2)
sns.boxplot(data = creditcard, y = "Amount", ax=ax2)

ax3 = plt.subplot(6, 5, 3)
sns.boxplot(data = creditcard, y = "V1", ax=ax3)

ax4 = plt.subplot(6, 5, 4)
sns.boxplot(data = creditcard, y = "V2", ax=ax4)

ax5 = plt.subplot(6, 5, 5)
sns.boxplot(data = creditcard, y = "V3", ax=ax5)

ax6 = plt.subplot(6, 5, 6)
sns.boxplot(data = creditcard, y = "V4", ax=ax6)

ax7 = plt.subplot(6, 5, 7)
sns.boxplot(data = creditcard, y = "V5", ax=ax7)

ax8 = plt.subplot(6, 5, 8)
sns.boxplot(data = creditcard, y = "V6", ax=ax8)

ax9 = plt.subplot(6, 5, 9)
sns.boxplot(data = creditcard, y = "V7", ax=ax9)

ax10 = plt.subplot(6, 5, 10)
sns.boxplot(data = creditcard, y = "V8", ax=ax10)

ax11 = plt.subplot(6, 5, 11)
sns.boxplot(data = creditcard, y = "V9", ax=ax11)

ax12 = plt.subplot(6, 5, 12)
sns.boxplot(data = creditcard, y = "V10", ax=ax12)

ax13 = plt.subplot(6, 5, 13)
sns.boxplot(data = creditcard, y = "V11", ax=ax13)

ax14 = plt.subplot(6, 5, 14)
sns.boxplot(data = creditcard, y = "V12", ax=ax14)

ax15 = plt.subplot(6, 5, 15)
sns.boxplot(data = creditcard, y = "V13", ax=ax15)

ax16 = plt.subplot(6, 5, 16)
sns.boxplot(data = creditcard, y = "V14", ax=ax16)

ax17 = plt.subplot(6, 5, 17)
sns.boxplot(data = creditcard, y = "V15", ax=ax17)

ax18 = plt.subplot(6, 5, 18)
sns.boxplot(data = creditcard, y = "V16", ax=ax18)

ax19 = plt.subplot(6, 5, 19)
sns.boxplot(data = creditcard, y = "V17", ax=ax19)

ax20 = plt.subplot(6, 5, 20)
sns.boxplot(data = creditcard, y = "V18", ax=ax20)

ax21 = plt.subplot(6, 5, 21)
sns.boxplot(data = creditcard, y = "V19", ax=ax21)

ax22 = plt.subplot(6, 5, 22)
sns.boxplot(data = creditcard, y = "V20", ax=ax22)

ax23 = plt.subplot(6, 5, 23)
sns.boxplot(data = creditcard, y = "V21", ax=ax23)

ax24 = plt.subplot(6, 5, 24)
sns.boxplot(data = creditcard, y = "V22", ax=ax24)

ax25 = plt.subplot(6, 5, 25)
sns.boxplot(data = creditcard, y = "V23", ax=ax25)

ax26 = plt.subplot(6, 5, 26)
sns.boxplot(data = creditcard, y = "V24", ax=ax26)

ax27 = plt.subplot(6, 5, 27)
sns.boxplot(data = creditcard, y = "V25", ax=ax27)

ax28 = plt.subplot(6, 5, 28)
sns.boxplot(data = creditcard, y = "V26", ax=ax28)

ax29 = plt.subplot(6, 5, 29)
sns.boxplot(data = creditcard, y = "V27", ax=ax29)

ax30 = plt.subplot(6, 5, 30)
sns.boxplot(data = creditcard, y = "V28", ax=ax30)

plt.show()

# %% [markdown]
# From the boxplots, we can see many outliers. Outliers tend to have more significant weight and have a negative impact on the analysis if they are not treated properly for small datasets. Since our dataset is large and outliers are expected in our fradulent credit card transactions data, these are unlikely errors in data, so we will keep the outliers for our analysis.

# %% [markdown]
# ### <a id="c2_ID"> 3.2 Histograms</a>

# %% [markdown]
# Histograms display the distribution of numerical data. It is an estimate of the probability distribution of continuous variables. They can have normal, right-skewed (positively skewed), or left-skewed (negatively skewed) distribution.

# %%
# Histograms for all numeric features
fig = plt.figure(figsize=(40,30))

ax1 = plt.subplot(6, 5, 1)
sns.distplot(creditcard["Time"], kde = False, rug = True, ax=ax1)

ax2 = plt.subplot(6, 5, 2)
sns.distplot(creditcard["Amount"], kde = False, rug = True, ax=ax2)

ax3 = plt.subplot(6, 5, 3)
sns.distplot(creditcard["V1"], kde = False, rug = True, ax=ax3)

ax4 = plt.subplot(6, 5, 4)
sns.distplot(creditcard["V2"], kde = False, rug = True, ax=ax4)

ax5 = plt.subplot(6, 5, 5)
sns.distplot(creditcard["V3"], kde = False, rug = True, ax=ax5)

ax6 = plt.subplot(6, 5, 6)
sns.distplot(creditcard["V4"], kde = False, rug = True, ax=ax6)

ax7 = plt.subplot(6, 5, 7)
sns.distplot(creditcard["V5"], kde = False, rug = True, ax=ax7)

ax8 = plt.subplot(6, 5, 8)
sns.distplot(creditcard["V6"], kde = False, rug = True, ax=ax8)

ax9 = plt.subplot(6, 5, 9)
sns.distplot(creditcard["V7"], kde = False, rug = True, ax=ax9)

ax10 = plt.subplot(6, 5, 10)
sns.distplot(creditcard["V8"], kde = False, rug = True, ax=ax10)

ax11 = plt.subplot(6, 5, 11)
sns.distplot(creditcard["V9"], kde = False, rug = True, ax=ax11)

ax12 = plt.subplot(6, 5, 12)
sns.distplot(creditcard["V10"], kde = False, rug = True, ax=ax12)

ax13 = plt.subplot(6, 5, 13)
sns.distplot(creditcard["V11"], kde = False, rug = True, ax=ax13)

ax14 = plt.subplot(6, 5, 14)
sns.distplot(creditcard["V12"], kde = False, rug = True, ax=ax14)

ax15 = plt.subplot(6, 5, 15)
sns.distplot(creditcard["V13"], kde = False, rug = True, ax=ax15)

ax16 = plt.subplot(6, 5, 16)
sns.distplot(creditcard["V14"], kde = False, rug = True, ax=ax16)

ax17 = plt.subplot(6, 5, 17)
sns.distplot(creditcard["V15"], kde = False, rug = True, ax=ax17)

ax18 = plt.subplot(6, 5, 18)
sns.distplot(creditcard["V16"], kde = False, rug = True, ax=ax18)

ax19 = plt.subplot(6, 5, 19)
sns.distplot(creditcard["V17"], kde = False, rug = True, ax=ax19)

ax20 = plt.subplot(6, 5, 20)
sns.distplot(creditcard["V18"], kde = False, rug = True, ax=ax20)

ax21 = plt.subplot(6, 5, 21)
sns.distplot(creditcard["V19"], kde = False, rug = True, ax=ax21)

ax22 = plt.subplot(6, 5, 22)
sns.distplot(creditcard["V20"], kde = False, rug = True, ax=ax22)

ax23 = plt.subplot(6, 5, 23)
sns.distplot(creditcard["V21"], kde = False, rug = True, ax=ax23)

ax24 = plt.subplot(6, 5, 24)
sns.distplot(creditcard["V22"], kde = False, rug = True, ax=ax24)

ax25 = plt.subplot(6, 5, 25)
sns.distplot(creditcard["V23"], kde = False, rug = True, ax=ax25)

ax26 = plt.subplot(6, 5, 26)
sns.distplot(creditcard["V24"], kde = False, rug = True, ax=ax26)

ax27 = plt.subplot(6, 5, 27)
sns.distplot(creditcard["V25"], kde = False, rug = True, ax=ax27)

ax28 = plt.subplot(6, 5, 28)
sns.distplot(creditcard["V26"], kde = False, rug = True, ax=ax28)

ax29 = plt.subplot(6, 5, 29)
sns.distplot(creditcard["V27"], kde = False, rug = True, ax=ax29)

ax30 = plt.subplot(6, 5, 30)
sns.distplot(creditcard["V28"], kde = False, rug = True, ax=ax30)

plt.show()

# %% [markdown]
# Because this is a large dataset, we will not be using Shapiro test to test for normality. From the histograms, we get a sense of the following distributions.
# Normal: V5, V6, V7, V9, V13, V19, V20, V21, V22, V27
# Right-skewed: Amount, V4, V11, V15, V24, V26, V28
# Left-skewed: V1, V2, V3, V8, V10, V12, V14, V16, V17, V18, V23, V25
# Bimodal: Time
# Since the majority of the numeric features are not normally distributed, we will need to perform non-paramteric tests for our analysis.
