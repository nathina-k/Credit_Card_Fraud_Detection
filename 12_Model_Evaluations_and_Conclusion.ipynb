[0.9928241132352111, 0.0071758867647888636, 0.8392857142857143, 0.9930669302456933, 0.1606837606837607, 0.006933069754306693, 0.26972740315638455, 0.9161763222657038],
[0.9896379631196075, 0.0103620368803925, 0.8303571428571429, 0.989889861621011, 0.11495673671199011, 0.010110138378988985, 0.2019543973941368, 0.9101235022390769],                 
[0.968646027180962, 0.031353972819037956, 0.875, 0.9687941259531205, 0.04246100519930676, 0.03120587404687941, 0.0809917355371901, 0.9218970629765603]]
columns=['Classification Accuracy', 'Classification Error', 'Sensitivity/Recall', 'Specificity', 'Precision', 'False Positive Rate', 'F-measure', 'AUC' ]
index =['Logistic Regression', 'Logistic Regression + RFE', 'Logistic Regression + PCA', 'Naive Bayes', 'Naive Bayes + RFE', 'Naive Bayes + PCA', 'KNN Classifier', 'KNN Classifier + RFE', 'KNN Classifier + PCA', 'Decision Tree', 'Decision Tree + RFE', 'Decision Tree + PCA', 'Random Forest', 'Random Forest + RFE', 'Random Forest + PCA', 'SVM Classifier', 'SVM Classifier + RFE', 'SVM Classifier + PCA', 'MLP', 'MLP + RFE', 'MLP + PCA']

# %%
# Dataframe showing evaluation metric values, evaluation metrics used, and machine learning models trained and tested
metrics_df = pd.DataFrame(metric_values, columns = columns, index = index)
metrics_df
# Out:
#                            Classification Accuracy  Classification Error  \
# Logistic Regression                       0.974074              0.025926
# Logistic Regression + RFE                 0.973975              0.026025
# Logistic Regression + PCA                 0.973242              0.026758
# Naive Bayes                               0.975737              0.024263
# Naive Bayes + RFE                         0.976583              0.023417
# Naive Bayes + PCA                         0.961005              0.038995
# KNN Classifier                            0.999337              0.000663
# KNN Classifier + RFE                      0.999337              0.000663
# KNN Classifier + PCA                      0.998914              0.001086
# Decision Tree                             0.997039              0.002961
# Decision Tree + RFE                       0.997110              0.002890
# Decision Tree + PCA                       0.996997              0.003003
# ...

# %%
# Heatmap showing evaluation metric values, evaluation metrics used, and machine learning models trained and tested
plt.figure(figsize=(20,12))
sns.heatmap(metrics_df, annot=True, fmt='.5f', cbar=True,
            xticklabels = columns, cmap="coolwarm", linecolor='black', linewidths=1,
            yticklabels = index)
plt.xlabel('Evaluation Metrics')
plt.ylabel('Classification Models')
plt.show()

# %% [markdown]
# Classification accuracies for all the models are greater than 97%. Since our dataset is highly imbalanced, sensitivity and F-measure evaluation metrics will better represent the model performances. Using sensitivity and F-measure metrics, the best performing model for our dataset is Random Forest followed by KNN Classifier. In particular, they perform better without RFE or PCA, then with RFE, then with PCA. Models that did not perform well are Logistic Regression, Naive Bayes, SVM and MLP.

# %% [markdown]
# In conclusion, after scaling the features and taking care of the high class imbalance by oversampling the majority class using SMOTE, classifcation models were built without RFE or PCA, with RFE, and with PCA. Classification models included logistic regression, Naive Bayes, KNN Classifier, Decision Tree, Random Forest, SVM Classifier, and MLP. Of these 21 models, Random Forest was the best performing model in detecting credit card fraud with an accuracy of 99.95%, sensitivity of 80.36% and F-measure of 84.51%.
# For future work, for RFE, logistic rgression was used as it was more time effiencent, SVM and random forest could be investigated to see if they give better results for RFE. Other feature selection methods can be explored like filter-based or hybrid-based methods. We can conclude that PCA did not perform as well as RFE. Also, additional algorithms and different number of trees for random forest could be investigated based on literature review.
