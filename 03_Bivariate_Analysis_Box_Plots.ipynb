# %% [markdown]
# # <font color='blue'>Credit Card Fraud Detecion</font>

# %% [markdown]
# ## Table of Contents
# 4. [Bivariate Analysis](#d_ID)
#
#     4.1 [Box Plots](#d1_ID)

# %% [markdown]
# ## <a id="d_ID"> 4. Bivariate Analysis</a>

# %% [markdown]
# ### <a id="d1_ID"> 4.1 Box Plots</a>

# %%
# Box plots for all numeric features by Class
fig = plt.figure(figsize=(40,30))

ax1 = plt.subplot(6, 5, 1)
sns.boxplot(data=creditcard, x="Class", y="Time", ax=ax1)

ax2 = plt.subplot(6, 5, 2)
sns.boxplot(data=creditcard, x="Class", y="Amount", ax=ax2)

ax3 = plt.subplot(6, 5, 3)
sns.boxplot(data=creditcard, x="Class", y="V1", ax=ax3)

ax4 = plt.subplot(6, 5, 4)
sns.boxplot(data=creditcard, x="Class", y="V2", ax=ax4)

ax5 = plt.subplot(6, 5, 5)
sns.boxplot(data=creditcard, x="Class", y="V3", ax=ax5)

ax6 = plt.subplot(6, 5, 6)
sns.boxplot(data=creditcard, x="Class", y="V4", ax=ax6)

ax7 = plt.subplot(6, 5, 7)
sns.boxplot(data=creditcard, x="Class", y="V5", ax=ax7)

ax8 = plt.subplot(6, 5, 8)
sns.boxplot(data=creditcard, x="Class", y="V6", ax=ax8)

ax9 = plt.subplot(6, 5, 9)
sns.boxplot(data=creditcard, x="Class", y="V7", ax=ax9)

ax10 = plt.subplot(6, 5, 10)
sns.boxplot(data=creditcard, x="Class", y="V8", ax=ax10)

ax11 = plt.subplot(6, 5, 11)
sns.boxplot(data=creditcard, x="Class", y="V9", ax=ax11)

ax12 = plt.subplot(6, 5, 12)
sns.boxplot(data=creditcard, x="Class", y="V10", ax=ax12)

ax13 = plt.subplot(6, 5, 13)
sns.boxplot(data=creditcard, x="Class", y="V11", ax=ax13)

ax14 = plt.subplot(6, 5, 14)
sns.boxplot(data=creditcard, x="Class", y="V12", ax=ax14)

ax15 = plt.subplot(6, 5, 15)
sns.boxplot(data=creditcard, x="Class", y="V13", ax=ax15)

ax16 = plt.subplot(6, 5, 16)
sns.boxplot(data=creditcard, x="Class", y="V14", ax=ax16)

ax17 = plt.subplot(6, 5, 17)
sns.boxplot(data=creditcard, x="Class", y="V15", ax=ax17)

ax18 = plt.subplot(6, 5, 18)
sns.boxplot(data=creditcard, x="Class", y="V16", ax=ax18)

ax19 = plt.subplot(6, 5, 19)
sns.boxplot(data=creditcard, x="Class", y="V17", ax=ax19)

ax20 = plt.subplot(6, 5, 20)
sns.boxplot(data=creditcard, x="Class", y="V18", ax=ax20)

ax21 = plt.subplot(6, 5, 21)
sns.boxplot(data=creditcard, x="Class", y="V19", ax=ax21)

ax22 = plt.subplot(6, 5, 22)
sns.boxplot(data=creditcard, x="Class", y="V20", ax=ax22)

ax23 = plt.subplot(6, 5, 23)
sns.boxplot(data=creditcard, x="Class", y="V21", ax=ax23)

ax24 = plt.subplot(6, 5, 24)
sns.boxplot(data=creditcard, x="Class", y="V22", ax=ax24)

ax25 = plt.subplot(6, 5, 25)
sns.boxplot(data=creditcard, x="Class", y="V23", ax=ax25)

ax26 = plt.subplot(6, 5, 26)
sns.boxplot(data=creditcard, x="Class", y="V24", ax=ax26)

ax27 = plt.subplot(6, 5, 27)
sns.boxplot(data=creditcard, x="Class", y="V25", ax=ax27)

ax28 = plt.subplot(6, 5, 28)
sns.boxplot(data=creditcard, x="Class", y="V26", ax=ax28)

ax29 = plt.subplot(6, 5, 29)
sns.boxplot(data=creditcard, x="Class", y="V27", ax=ax29)

ax30 = plt.subplot(6, 5, 30)
sns.boxplot(data=creditcard, x="Class", y="V28", ax=ax30)

plt.show()

# %% [markdown]
# The boxplots in blue represent the genuine transactions and the boxplots in orange represent the fradulent transactions. The boxplots of numeric features by class show clear differences for Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V14, V16, V17, V18, V19, V21, V24, and V27. The boxplots of numeric features by class show similarities for Amount, V13, V15, V20, V22, V23, V25, V26, and V27. It is interesting to note that across all genuine transactions boxplots (blue boxplots), there tends to be significantly higher number of outliers present except for the Time feature. This tells us that outliers are to be expected in the genuine transactions. But it is also important to keep in mind, there are significantly larger number of genuine transactions data points (99.83%) than there are fraudulent transactions data points (0.17%) in the dataset.
